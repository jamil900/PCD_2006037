# %% [markdown]
# <a href="https://colab.research.google.com/github/jamil900/PCD_2006037/blob/main/Latihan03/Image_Processing_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import keras
from google.colab.patches import cv2_imshow
from keras import layers
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive 
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
lena = cv2.imread("/content/drive/MyDrive/PCD/lena.jpeg")

# %%
print("lena")
cv2_imshow(lena)
# Out:
# lena
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F7A26287400>

# %%
lena_grey = (cv2.cvtColor(lena, cv2.COLOR_BGR2GRAY))
print("lena Abu")
cv2_imshow(lena_grey)
# Out:
# lena Abu
# <PIL.Image.Image image mode=L size=225x225 at 0x7F7A2736A520>

# %%
def gauss_noise(image, gauss_var=1000):
    mean = 0
    sigma = gauss_var ** 0.5
    gauss = np.random.normal(mean, sigma, image.shape)

    res = image + gauss
    noisy = np.clip(res, 0, 255).astype(np.uint8)
    return noisy

# %%
lena_noisy = gauss_noise(lena_grey, gauss_var=25)
print("lena Abu Noisy")
cv2_imshow(lena_noisy)
# Out:
# lena Abu Noisy
# <PIL.Image.Image image mode=L size=225x225 at 0x7F7A2479ACD0>

# %%
lena_colored_noisy = gauss_noise(lena, gauss_var=25)
print("lena Colored Noisy")
cv2_imshow(lena_colored_noisy)
# Out:
# lena Colored Noisy
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F7A25FF36D0>
